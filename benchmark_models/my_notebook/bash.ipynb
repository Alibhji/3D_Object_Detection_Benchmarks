# %%
# !cat ./train_bash.sh
# Out:
# #!/usr/bin/env bash
#
# set -x
# NGPUS=$1
# PY_ARGS=${@:2}
# cd ../../tools/
#
# python -m torch.distributed.launch --nproc_per_node=${NGPUS} train.py --launcher pytorch ${PY_ARGS}

# %%
#     print("--------------------------->>>>>>>>>>>>>>>>>>>>>>>>")
#     iiii=1
#     print(train_set[iiii].keys())
#     print('points',train_set[iiii]['points'].shape)
#     print('frame_id',train_set[iiii]['frame_id'])
#     print('gt_boxes',train_set[iiii]['gt_boxes'].shape)
#     print('use_lead_xyz',train_set[iiii]['use_lead_xyz'])
#     print('voxels',train_set[iiii]['voxels'].shape)
#     print('voxel_coords',train_set[iiii]['voxel_coords'].shape)
#     print('voxel_num_points',train_set[iiii]['voxel_num_points'].shape)
#     print('image_shape',train_set[iiii]['image_shape'])
    
    
#     print("--------------------------->>>>>>>>>>>>>>>>>>>>>>>>")
    
#     bbbbbbbbbbbbbbbbbb

# %%
# !bash train_bash.sh  4  --cfg_file cfgs/kitti_models/pointrcnn.yaml  --batch_size 32  --epochs 80

# %%
# !cd ../../tools/ && python  train.py  --cfg_file  cfgs/kitti_models/pointrcnn.yaml --batch_size 1  --epochs 80
# Out:
# fatal: Not a git repository (or any parent up to mount point /app/OpenPCDet/tools)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# Namespace(batch_size=1, cfg_file='cfgs/kitti_models/pointrcnn.yaml', ckpt=None, ckpt_save_interval=1, epochs=80, extra_tag='default', fix_random_seed=False, launcher='none', local_rank=0, max_ckpt_save_num=30, max_waiting_mins=0, merge_all_iters_to_one_epoch=False, pretrained_model=None, save_to_file=False, set_cfgs=None, start_epoch=0, sync_bn=False, tcp_port=18888, workers=8)
# 2020-08-11 17:36:51,509   INFO  **********************Start logging**********************
# 2020-08-11 17:36:51,509   INFO  CUDA_VISIBLE_DEVICES=ALL
# 2020-08-11 17:36:51,509   INFO  cfg_file         cfgs/kitti_models/pointrcnn.yaml
# 2020-08-11 17:36:51,510   INFO  batch_size       1
# 2020-08-11 17:36:51,510   INFO  epochs           80
# 2020-08-11 17:36:51,510   INFO  workers          8
# 2020-08-11 17:36:51,510   INFO  extra_tag        default
# ...

# %%
# !pip install torch-summary

# %%
from torchsummary import summary
